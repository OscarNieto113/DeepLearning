# %% [markdown]
# # Deep Learning model implementation
#
# Oscar Eduardo Nieto Espitia - A01705090

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential

import glob, os

# Set a random seed for reproducibility
random.seed(42)

# %% [markdown]
# Here, I define the path to the dataset and use the glob module to create a list of image file paths in the dataset.
#
# The Garbage Classification Dataset is a collection of images of various types of waste items, which have been categorized into six different classes. Each class represents a specific type of garbage, and the dataset provides images for each class.
#
# Cardboard: 393 images
# Glass: 491 images
# Metal: 400 images
# Paper: 584 images
# Plastic: 472 images
# Trash: 127 images

# %%
base_path = './data/garbage classification/Garbage classification'
img_list = glob.glob(os.path.join(base_path, '*/*.jpg'))

print(len(img_list))
# Out:
# 2527

# %%
rows, cols = 2, 3
fig, axes = plt.subplots(rows, cols, figsize=(10, 6))

for i, ax in enumerate(axes.flat):
    img_path = random.choice(img_list)
    img = load_img(img_path)
    img = img_to_array(img, dtype=np.uint8)

    ax.imshow(img.squeeze())
    ax.set_title(f"Image {i+1}")

plt.tight_layout()
plt.show()

# %%
# No data augmentation for the test/validation datasets
test_datagen = ImageDataGenerator(
    rescale=1./255
)

# Create a generator for the training data
train_generator = train_datagen.flow_from_directory(
    base_path,
    target_size=(300, 300),
    batch_size=16,
    class_mode='categorical',
    subset='training',
    seed=0
)

# Create a generator for the validation data (no data augmentation)
validation_generator = test_datagen.flow_from_directory(
    base_path,
    target_size=(300, 300),
    batch_size=16,
    class_mode='categorical',
    subset='validation',
    seed=0
)

# Map class indices to class labels
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())

print(labels)
# Out:
# Found 2276 images belonging to 6 classes.
# Found 0 images belonging to 6 classes.
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
model = Sequential([
    Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(300, 300, 3)),
    MaxPooling2D(pool_size=2),

    Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'),
    MaxPooling2D(pool_size=2),
    
    Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'),
    MaxPooling2D(pool_size=2),
    
    Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'),
    MaxPooling2D(pool_size=2),

    Flatten(),

    Dense(64, activation='relu'),

    Dense(6, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 300, 300, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 150, 150, 32)      0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 150, 150, 64)      18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 75, 75, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 75, 75, 32)        18464
#
#  max_pooling2d_6 (MaxPoolin  (None, 37, 37, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 37, 37, 32)        9248
#
#  max_pooling2d_7 (MaxPoolin  (None, 18, 18, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 10368)             0
#
#  dense_2 (Dense)             (None, 64)                663616
#
#  dense_3 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 711110 (2.71 MB)
# Trainable params: 711110 (2.71 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit_generator(train_generator, epochs=20, validation_data=validation_generator)
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_19932\3189617050.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_generator, epochs=20, validation_data=validation_generator)
# Epoch 1/20
# 143/143 [==============================] - 82s 570ms/step - loss: 1.6817 - acc: 0.2562 - val_loss: 1.6378 - val_acc: 0.3108
# Epoch 2/20
# 143/143 [==============================] - 81s 565ms/step - loss: 1.5143 - acc: 0.3673 - val_loss: 1.4493 - val_acc: 0.4024
# Epoch 3/20
# 143/143 [==============================] - 82s 570ms/step - loss: 1.3641 - acc: 0.4482 - val_loss: 1.4236 - val_acc: 0.4223
# Epoch 4/20
# 143/143 [==============================] - 87s 606ms/step - loss: 1.2950 - acc: 0.4754 - val_loss: 1.3154 - val_acc: 0.4582
